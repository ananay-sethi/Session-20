# %% [markdown]
# # Fitting Kepler-10 Data
#
# In this workbook we'll go through the process of fitting Kepler data with linear models.

# %%
import pickle

import matplotlib.pyplot as plt
import numpy as np
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
workbook_data = pickle.load(open("data/workbook_1.p", "rb"))
x, y, ye = workbook_data["x"], workbook_data["y"], workbook_data["ye"]
y, ye = y / y.mean(), ye / y.mean()
period, t0, duration = (
    workbook_data["period"],
    workbook_data["t0"],
    workbook_data["duration"],
)

# %%
fig, ax = plt.subplots()
ax.errorbar(x, y, ye, color="k", lw=1)
ax.set(xlabel="Time [BKJD]", ylabel="Flux [e-/s]", title="Kepler-10")
# Out:
# [Text(0.5, 0, 'Time [BKJD]'),
#  Text(0, 0.5, 'Flux [e-/s]'),
#  Text(0.5, 1.0, 'Kepler-10')]

# %% [markdown]
# ## Step 1: Create a design matrix
#
# Create a design matrix for the data above. The design matrix should consist of two "box" transit models (one for each planet) where the model is 0 outside of transit, and -1 during transit. The design matrix should have three vectors, including the first vector which is an offset term.
#
# Overwrite `A` below to be your design matrix.

# %%
planets = -np.asarray([((x - t0[idx]) % period[idx] < duration[idx] / 2) for idx in range(2)], float).T
A = np.vstack([x**0, * planets.T]).T

# %%
assert np.isclose(A.dot([1, 0.1, 0.2]).sum(), 1614.5, atol=0.1)

# %% [markdown]
# ## Step 2: Find the best fitting weights
# Use the Weighted Least Squares equation to find the mean best fitting weights.
#
# Overwrite `w` below to be your mean best fitting weights.

# %%
sigma_w_inv = A.T.dot(A/ye[:, None]**2)
B = A.T.dot(y/ye**2)
w = np.linalg.solve(sigma_w_inv, B)
w
# Out:
# array([1.00000907e+00, 1.43104255e-04, 4.47823457e-04])

# %% [markdown]
# This is implicitly fitting the transit depth for the planets. Set the transit depth for each planet in `td_1` and `td_2` below.

# %%
td_1, td_2 = w[1:]

# %%
assert np.isclose(td_1, 0.000143104, rtol=0.1)
assert np.isclose(td_2, 0.00044782345, rtol=0.1)

# %% [markdown]
# ## Step 3: Improving the model
#
# Assume that the stellar rotation period is `8.235401877719259` days. Create a model for the stellar variability and improve the fit for the transit depths.
#
# Use
#
# - A sinusoid to capture the stellar variability
# - Weighted Least Squares
# - A mask to remove outliers

# %%
stellar_rotation_period = 8.235401877719259

# %%
# sinusoid to get stellar variability

A = np.vstack([x**0, * planets.T]).T
w = np.linalg.solve(A.T.dot(A / ye[:, None] ** 2), A.T.dot(y / ye**2))
model = A.dot(w)
outliers = np.abs(y - A.dot(w)) / ye > 20
print(A.shape, planets.shape)
# Out:
# (1624, 3) (1624, 2)

# %%
# Weighted least squares
A = np.vstack([
    np.sin(2*np.pi*x / stellar_rotation_period), np.cos(2*np.pi*x / stellar_rotation_period),
    np.sin(4*np.pi*x / stellar_rotation_period), np.cos(4*np.pi*x / stellar_rotation_period),
    np.sin(6*np.pi*x / stellar_rotation_period), np.cos(6*np.pi*x / stellar_rotation_period),
    x**0,
]).T
A= np.hstack([A, planets])

# masking
mask = ~outliers
w = np.linalg.solve(A[mask].T.dot(A[mask]/ye[mask][:, None] ** 2), A[mask].T.dot(y[mask]/ye[mask][:, None] ** 2),)

print(A.shape)
# Out:
# (1624, 9)

# %%
fig, ax = plt.subplots()
ax.errorbar(x, y, ye, color="k", lw=1, label="Data")
ax.scatter(x[outliers], y[outliers], color="b", lw=1, label="Data", marker='x')
ax.plot(x, A.dot(w), c="r", zorder=10, label="Model")
ax.set(xlabel="Time [BKJD]", ylabel="Flux [e-/s]", title="Kepler-10");

# %%
assert np.allclose(w[-2:], np.asarray([0.00015893, 0.00040655]), rtol=0.02)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 assert np.allclose(w[-2:], np.asarray([0.00015893, 0.00040655]), rtol=0.02)
#
# File <__array_function__ internals>:200, in allclose(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.9/site-packages/numpy/core/numeric.py:2270, in allclose(a, b, rtol, atol, equal_nan)
#    2199 @array_function_dispatch(_allclose_dispatcher)
#    2200 def allclose(a, b, rtol=1.e-5, atol=1.e-8, equal_nan=False):
#    2201     """
#    2202     Returns True if two arrays are element-wise equal within a tolerance.
#    2203
#    (...)
#    2268
#    2269     """
# -> 2270     res = all(isclose(a, b, rtol=rtol, atol=atol, equal_nan=equal_nan))
#    2271     return bool(res)
#
# File <__array_function__ internals>:200, in isclose(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.9/site-packages/numpy/core/numeric.py:2380, in isclose(a, b, rtol, atol, equal_nan)
#    2378 yfin = isfinite(y)
#    2379 if all(xfin) and all(yfin):
# -> 2380     return within_tol(x, y, atol, rtol)
#    2381 else:
#    2382     finite = xfin & yfin
#
# File /opt/anaconda3/lib/python3.9/site-packages/numpy/core/numeric.py:2361, in isclose.<locals>.within_tol(x, y, atol, rtol)
#    2359 def within_tol(x, y, atol, rtol):
#    2360     with errstate(invalid='ignore'), _no_nep50_warning():
# -> 2361         return less_equal(abs(x-y), atol + rtol * abs(y))
#
# ValueError: operands could not be broadcast together with shapes (2,1622) (2,)
